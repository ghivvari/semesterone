# %% [markdown]
# Modul 1 soal 2,c

# %%
A = 5
B = 50.0
C = 50
D = '23yearsold'
E = 5
F = D
G = 567_100
H = 1e14
I = True
J = 1000-25
# Out:
# 2599950483824

# %% [markdown]
# Modul 1 soal 3

# %%
import math

print("Masukkan berat: (kg)")
berat = float(input())

print("Masukkan Tinggi: (m)")
tinggi = float(input())

Bmi = berat / (tinggi ** 2)
print(f"Nilai BMI Anda adalah: {Bmi:.2f}")
# Out:
# Masukkan berat: (kg)
# Masukkan Tinggi: (m)
# Nilai BMI Anda adalah: 31.11

# %% [markdown]
# Modul 2 soal 3

# %%
angka = float(input("Masukkan sebuah angka: "))

if angka > 0:
    print("Positif")
elif angka < 0:
    print("Negatif")
else:
    print("Nol")

# %% [markdown]
# Modul 2 soal 4

# %%
x = int(input("Masukan angka: \n"))
while x < 0:
    print("Masukan angka positif")
    x = int(input("Masukan angka: \n"))

print(f"Angka positif: {x}")
print(f"Nilai absolut dari angka tersebut adalah: {abs(x)}")

# %% [markdown]
# Modul 2 Soal 5

# %%
nilai = float(input("Masukkan nilai ujian (0-100): "))

if nilai >= 85:
    grade = "A"
elif nilai >= 70:
    grade = "B"
elif nilai >= 60:
    grade = "C"
elif nilai >= 50:
    grade = "D"
else:
    grade = "E"

print(f"Nilai ujian: {nilai}")
print(f"Grade: {grade}")
